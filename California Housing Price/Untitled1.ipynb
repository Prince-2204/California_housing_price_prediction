# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore') #for removing the unwanted warnings

# %%
data = pd.read_csv('housing.csv')  #reading the csv file

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.head() # checking the data
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.hist(figsize=(10,10))
plt.show()

# %%
data.plot(kind="scatter" , x="longitude" , y="latitude")
plt.show()

# %%
data.plot(kind="scatter" , x="longitude" , y="latitude" , alpha=0.4 , s=data["population"]/100 , label="population" , figsize=(10,7) , c = "median_house_value" , cmap = plt.get_cmap("jet"),colorbar = True)
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
train_set , test_set = train_test_split(data , test_size = 0.2 , random_state = 42) #Spliting between training and test set

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
# ...

# %%
data_heatmap = train_set.drop('ocean_proximity' , axis=1)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,5)) #Plotting heatmap for checking the correlation
sns.heatmap(data_heatmap.corr(),annot=True)
plt.show()

# %%
train_set.duplicated().sum() #checking for duplicates
# Out:
# 0

# %%
train_set.shape
# Out:
# (16512, 10)

# %%
test_set.shape
# Out:
# (4128, 10)

# %%
data.shape
# Out:
# (20640, 10)

# %%
train_set.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924485           -0.101818     0.038676
# latitude            -0.924485  1.000000            0.005296    -0.029224
# housing_median_age  -0.101818  0.005296            1.000000    -0.360922
# total_rooms          0.038676 -0.029224           -0.360922     1.000000
# total_bedrooms       0.063064 -0.059998           -0.320624     0.930489
# population           0.094276 -0.102499           -0.292283     0.857936
# households           0.049306 -0.064061           -0.302796     0.920482
# median_income       -0.017040 -0.076571           -0.121711     0.198268
# median_house_value  -0.046349 -0.142983            0.103706     0.133989
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.063064    0.094276    0.049306      -0.017040
# latitude                 -0.059998   -0.102499   -0.064061      -0.076571
# ...

# %%
housing_f = train_set.drop('median_house_value' , axis=1)
housing_labels = train_set['median_house_value']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
housing_num = housing_f.drop('ocean_proximity' , axis = 1)
housing_cat = housing_f['ocean_proximity']

# %%
housing_cat
# Out:
# 14196    NEAR OCEAN
# 8267     NEAR OCEAN
# 17445    NEAR OCEAN
# 14265    NEAR OCEAN
# 2271         INLAND
#             ...
# 11284     <1H OCEAN
# 11964        INLAND
# 5390      <1H OCEAN
# 860       <1H OCEAN
# 15795      NEAR BAY
# Name: ocean_proximity, Length: 16512, dtype: object

# %%
num_pipeline = Pipeline([
    
    ('imputer',SimpleImputer(strategy = "median")),
    ('std_scaler' , StandardScaler()),
]
)

# %%
num_attribs = list(housing_num)
cat_attribs = ['ocean_proximity']

# %%
from sklearn.compose import ColumnTransformer

# %%
full_pipeline = ColumnTransformer([
    
    ("num" , num_pipeline , num_attribs),
    ("cat",OneHotEncoder() ,cat_attribs ),
    
])

# %%
housing_prepared = full_pipeline.fit_transform(housing_f)

# %%
housing_prepared
# Out:
# array([[ 1.27258656, -1.3728112 ,  0.34849025, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.70916212, -0.87669601,  1.61811813, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.44760309, -0.46014647, -1.95271028, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 0.59946887, -0.75500738,  0.58654547, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.18553953,  0.90651045, -1.07984112, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.41489815,  0.99543676,  1.85617335, ...,  0.        ,
#          1.        ,  0.        ]])

# %% [markdown]
# # Training Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(housing_prepared , housing_labels)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

# %%
housing_predict = lin_reg.predict(housing_prepared)
lin_mse = mean_squared_error(housing_labels , housing_predict)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 68433.93736666226

# %%
from sklearn.model_selection import cross_val_score

# %%
lin_score = cross_val_score(lin_reg , housing_prepared , housing_labels , scoring = "neg_mean_squared_error" , cv = 10)
lin_rmse_score = np.sqrt(-lin_score)

# %%
def display_score(score):
    print("Scores: ", score)
    print("Mean: ", score.mean())
    print("Standard Scaler: " , score.std())

# %%
display_score(lin_rmse_score)
# Out:
# Scores:  [65584.92927702 71711.35784404 68143.02388491 66855.55244479
#  69440.38017435 65640.36503235 65861.37192245 69898.33048393
#  73117.94692191 69704.17693297]
# Mean:  68595.74349187134
# Standard Scaler:  2496.105310731916

# %% [markdown]
# # Training DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing_prepared , housing_labels)
# Out:
# DecisionTreeRegressor()

# %%
tree_predict = tree_reg.predict(housing_prepared)
tree_mse = mean_squared_error(housing_labels , housing_predict)
tree_rmse = np.sqrt(tree_mse)

# %%
tree_score = cross_val_score(tree_reg , housing_prepared , housing_labels,scoring = "neg_mean_squared_error" , cv = 10)
tree_rmse_score = np.sqrt(-tree_score)

# %%
display_score(tree_rmse_score)
# Out:
# Scores:  [66995.00635266 69216.4351969  68325.80936843 70561.22265707
#  68748.96000076 67227.45484519 63452.89271942 70527.27132737
#  68167.79973137 69102.42315092]
# Mean:  68232.52753500897
# Standard Scaler:  1951.3993736140278

# %% [markdown]
# # Training Random Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_reg = RandomForestRegressor()
random_reg.fit(housing_prepared , housing_labels)
# Out:
# RandomForestRegressor()

# %%
random_predict = random_reg.predict(housing_prepared)
random_mse = mean_squared_error(housing_labels , housing_predict)
random_rmse = np.sqrt(random_mse)

# %%
random_score = cross_val_score(random_reg , housing_prepared , housing_labels,scoring = "neg_mean_squared_error" , cv = 10)
random_rmse_score = np.sqrt(-random_score)

# %%
display_score(random_rmse_score)
# Out:
# Scores:  [46737.57773753 50693.89198676 47360.76433094 50659.47092791
#  50368.70348809 46772.4093351  45765.28510198 50685.55972035
#  49544.97873145 50053.38692366]
# Mean:  48864.20282837846
# Standard Scaler:  1865.234045830442

# %% [markdown]
# # Training Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge(alpha=1 , solver='cholesky')
ridge_reg.fit(housing_prepared,housing_labels)
# Out:
# Ridge(alpha=1, solver='cholesky')

# %%
ridge_predict = ridge_reg.predict(housing_prepared)
ridge_mse = mean_squared_error(housing_labels , housing_predict)
ridge_rmse = np.sqrt(ridge_mse)

# %%
ridge_score = cross_val_score(ridge_reg , housing_prepared , housing_labels , scoring = "neg_mean_squared_error" , cv=10)
ridge_rmse_score = np.sqrt(-ridge_score)

# %%
display_score(ridge_rmse_score)
# Out:
# Scores:  [65581.98451191 71697.67453292 68143.00568465 66856.07977026
#  69474.0335953  65641.45227247 65819.76934297 69897.08432643
#  73126.84200419 69705.7400104 ]
# Mean:  68594.3666051496
# Standard Scaler:  2501.955202603065

# %% [markdown]
# # Training Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(housing_prepared , housing_labels)
# Out:
# Lasso(alpha=0.1)

# %%
lasso_predict = lasso_reg.predict(housing_prepared)
lasso_mse = mean_squared_error(housing_labels , housing_predict)
lasso_rmse = np.sqrt(lasso_mse)

# %%
lasso_score = cross_val_score(lasso_reg , housing_prepared , housing_labels , scoring = "neg_mean_squared_error" , cv=10)
lasso_rmse_score = np.sqrt(-lasso_score)

# %%
display_score(lasso_rmse_score)
# Out:
# Scores:  [65581.50845401 71711.06751842 68143.02865953 66855.52668675
#  69441.09142441 65640.40166674 65860.75547719 69898.30136692
#  73117.97924662 69704.25781475]
# Mean:  68595.39183153398
# Standard Scaler:  2496.578774637626

# %% [markdown]
# # Training Elastic Net

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic_reg = ElasticNet(alpha=0.1 , l1_ratio=0.5)
elastic_reg.fit(housing_prepared , housing_labels)
# Out:
# ElasticNet(alpha=0.1)

# %%
elastic_predict = elastic_reg.predict(housing_prepared)
elastic_mse = mean_squared_error(housing_labels , housing_predict)
elastic_rmse = np.sqrt(elastic_mse)

# %%
elastic_score = cross_val_score(elastic_reg , housing_prepared , housing_labels , scoring = "neg_mean_squared_error" , cv = 10)
elastic_rmse_score = np.sqrt(-elastic_score)

# %%
display_score(elastic_rmse_score)
# Out:
# Scores:  [66802.97858502 72419.23207401 68917.38228286 67746.63434823
#  70805.29837161 67094.67934337 66682.30567434 70463.16584121
#  71390.40463001 71055.9649203 ]
# Mean:  69337.80460709476
# Standard Scaler:  2032.1815623159425

# %% [markdown]
# # Training SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd_reg = SGDRegressor()
sgd_reg.fit(housing_prepared , housing_labels)
# Out:
# SGDRegressor()

# %%
sgd_predict = sgd_reg.predict(housing_prepared)
sgd_mse = mean_squared_error(housing_labels , housing_predict)
sgd_rmse = np.sqrt(sgd_mse)

# %%
sgd_score = cross_val_score(sgd_reg , housing_prepared , housing_labels , scoring = "neg_mean_squared_error" , cv=10)
sgd_rmse_score = np.sqrt(-sgd_score)

# %%
display_score(sgd_rmse_score)
# Out:
# Scores:  [65510.20548156 71732.40107325 68169.61802675 66911.655052
#  69855.6424866  65793.31231663 65806.16337983 70071.34307242
#  73111.85815189 70215.11748444]
# Mean:  68717.73165253756
# Standard Scaler:  2542.5552562432586

# %% [markdown]
# # Training SVM Regression

# %%
from sklearn.svm import LinearSVR

# %%
svm_reg = LinearSVR(epsilon=1.5)
svm_reg.fit(housing_prepared , housing_labels)
# Out:
# LinearSVR(epsilon=1.5)

# %%
svm_predict = svm_reg.predict(housing_prepared)
svm_mse = mean_squared_error(housing_labels , svm_predict)
svm_rmse = np.sqrt(svm_mse)

# %%
svm_score = cross_val_score(svm_reg , housing_prepared , housing_labels , scoring = "neg_mean_squared_error" , cv=10)
svm_rmse_score = np.sqrt(-svm_score)

# %%
display_score(svm_rmse_score)
# Out:
# Scores:  [222686.99866056 222498.17087698 223690.84251635 215825.78650673
#  219568.71233176 221685.32374908 216511.0379613  217367.11197525
#  221361.14442473 221706.94011343]
# Mean:  220290.20691161667
# Standard Scaler:  2656.362835362945

# %%
x = ['Linear Reg' , 'Ridge Reg' , 'Lasso Reg' , 'Elastic Net' , 'Decision Tree' , 'Random Forest' , 'SGDRegressor' , 'SVM']
y = [68595.74349187134 , 68594.3666051496 , 68595.39183153398 , 69337.80460709476 ,68232.46851080531 , 48824.60559816586,68738.26126861371,220290.20691161667 ]

# %%
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Evaluating the Test set

# %%
housing_test_f = test_set.drop('median_house_value' , axis=1)

# %%
housing_test_label = test_set['median_house_value']

# %%
housing_test_prepared = full_pipeline.transform(housing_test_f)

# %% [markdown]
# # Linear Regression

# %%
housing_lin_predict = lin_reg.predict(housing_test_prepared)

# %%
housing_lin_mse = mean_squared_error(housing_test_label,housing_lin_predict)
housing_lin_rmse = np.sqrt(housing_lin_mse)

# %%
housing_lin_rmse
# Out:
# 70059.19333925012

# %% [markdown]
# # Ridge Regression

# %%
housing_ridge_predict = ridge_reg.predict(housing_test_prepared)

# %%
housing_ridge_mse = mean_squared_error(housing_test_label , housing_ridge_predict)
housing_ridge_rmse = np.sqrt(housing_ridge_mse)

# %%
housing_ridge_rmse
# Out:
# 70066.02112093332

# %% [markdown]
# # Lasso Regression

# %%
housing_lasso_predict = lasso_reg.predict(housing_test_prepared)

# %%
housing_lasso_mse = mean_squared_error(housing_test_label , housing_lasso_predict)

# %%
housing_lasso_rmse = np.sqrt(housing_lasso_mse)

# %%
housing_lasso_rmse
# Out:
# 70059.30355077855

# %% [markdown]
# # Elastic Net

# %%
housing_elastic_predict = elastic_reg.predict(housing_test_prepared)

# %%
housing_elastic_mse = mean_squared_error(housing_test_label , housing_elastic_predict)
housing_elastic_rmse = np.sqrt(housing_elastic_mse)

# %%
housing_elastic_rmse
# Out:
# 70324.68500018607

# %% [markdown]
# # Decision Tree

# %%
housing_tree_predict = tree_reg.predict(housing_test_prepared)

# %%
housing_tree_mse = mean_squared_error(housing_test_label , housing_tree_predict)
housing_tree_rmse = np.sqrt(housing_tree_mse)
housing_tree_rmse
# Out:
# 69281.28607488405

# %% [markdown]
# # Random Forest

# %%
housing_random_predict = random_reg.predict(housing_test_prepared)
housing_random_mse = mean_squared_error(housing_test_label,housing_random_predict)

housing_random_rmse = np.sqrt(housing_random_mse)
housing_random_rmse
# Out:
# 49165.70122114768

# %% [markdown]
# # SVM Regressor

# %%
housing_svm_predict = svm_reg.predict(housing_test_prepared)
housing_svm_mse = mean_squared_error(housing_test_label,housing_svm_predict)
housing_svm_rmse = np.sqrt(housing_svm_mse)
housing_svm_rmse
# Out:
# 216450.90736962447

# %% [markdown]
# # Plotting the graph

# %%
x_test = ['Linear Reg' , 'Ridge Reg' , 'Lasso Reg' , 'Elastic Net' , 'Decision Tree' , 'Random Forest'  , 'SVM']
y_test = [housing_lin_rmse , housing_ridge_rmse , housing_lasso_rmse , housing_elastic_rmse ,housing_tree_rmse ,housing_random_rmse ,housing_svm_rmse]

# %%
plt.figure(figsize=(10,10))
plt.xlabel('Algorithm')
plt.ylabel('Corresponding RMSE')
plt.title('Comparison between different rmse score of different type of Algorithm')
plt.plot(x_test,y_test)
plt.show()

# %%
data = {'Algorithm Name': ['Linear Reg' , 'Ridge Reg' , 'Lasso Reg' , 'Elastic Net' , 'Decision Tree' , 'Random Forest'  , 'SVM'],
       'Rmse Score':[housing_lin_rmse , housing_ridge_rmse , housing_lasso_rmse , housing_elastic_rmse ,housing_tree_rmse ,housing_random_rmse ,housing_svm_rmse] }

# %%
df = pd.DataFrame(data , columns=['Algorithm Name' , 'Rmse Score'])

# %%
df
# Out:
#   Algorithm Name     Rmse Score
# 0     Linear Reg   70059.193339
# 1      Ridge Reg   70066.021121
# 2      Lasso Reg   70059.303551
# 3    Elastic Net   70324.685000
# 4  Decision Tree   69281.286075
# 5  Random Forest   49165.701221
# 6            SVM  216450.907370
